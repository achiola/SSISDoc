# %%
import os
ejemplo_dir = '\\\\agdgdap01\\g$\\SSIS_Desarrollo_ok\\Bienes de cambio V3'
with os.scandir(ejemplo_dir) as ficheros:
    subdirectorios = [fichero.name for fichero in ficheros if fichero.is_dir()]
print(subdirectorios)
# Out:
# ['Analisis Playa', 'BC Julio2', 'Bienes de cambio', 'dtsx bak', 'Ecuaciones', 'LogTest', 'OBJETOS_DB', 'Template DTSx - v1.0', 'v3 bad']

# %%
import os

nombre_carpeta = '\\\\agdgdap01\\g$\\SSIS_Desarrollo_ok\\Bienes de cambio V3'

contenido = os.listdir(nombre_carpeta)

for elemento in contenido:
    print(os.path.join(nombre_carpeta, elemento))
# Out:
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Analisis Playa
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\BC Julio2
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Bienes de cambio
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Bienes de cambio V4.dtproj.lnk
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\dtsx bak
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Ecuaciones
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Ecuaciones.sln
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Ecuaciones.suo
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Fallas de Proceso - Automático.xlsx
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\LogTest
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\OBJETOS_DB
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\psexec.exe
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\SQLDUMPER_ERRORLOG.log
# ...

# %%
import os
nombre_carpeta = '\\\\agdgdap01\\g$\\SSIS_Desarrollo_ok\\Bienes de cambio V3'
for e in os.walk(nombre_carpeta):
    # 0 = carpeta actual
    # 1 = subcarpetas
    # 2 = archivos
    for o in e[2]:
        if o[-5:] == '.dtsx':
            print(e[0], o, '-->', o[-5:])
# Out:
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3 xESP_ECU_PPAL (1).dtsx --> .dtsx
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3 xESP__Control_A_Fijar.dtsx --> .dtsx
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Analisis Playa Analisis__Dim_ANALISIS_Playa 20210208.dtsx --> .dtsx
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Analisis Playa Analisis__Dim_ANALISIS_Playa.dtsx --> .dtsx
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\BC Julio2\BC Julio2 Package.dtsx --> .dtsx
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Bienes de cambio AJUSTE__ECUACIONES_UNAGRO.dtsx --> .dtsx
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Bienes de cambio AJUSTE__ECUACIONES_UNCO.dtsx --> .dtsx
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Bienes de cambio AJUSTE__METRICAS_RESUMEN.dtsx --> .dtsx
# \\agdgdap01\g$\SSIS_Desarrollo_ok\Bienes de cambio V3\Bienes de cambio AJUSTE__METRICAS_RESUMEN_STOCK_FORZADO-POR FAMILIA.dtsx --> .dtsx
# ...

# %%
import os

# %%
os.
