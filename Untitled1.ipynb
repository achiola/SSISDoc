# %%
import xml2py
from xml.etree import cElementTree as ElementTree
import ssis_getCode as sgc
import xmltodict

# %%
xml = sgc.getSSISCode()
# Out:
# C:\Anaconda3\envs\test\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
dict = xmltodict.parse(xml)

# %%
dict
# Out:
# {'DTS:Executable': {'@xmlns:DTS': 'www.microsoft.com/SqlServer/Dts',
#   '@DTS:ExecutableType': 'SSIS.Package.2',
#   'DTS:Property': [{'@DTS:Name': 'PackageFormatVersion', '#text': '3'},
#    {'@DTS:Name': 'VersionComments'},
#    {'@DTS:Name': 'CreatorName', '#text': 'AGDCORP\\achiola'},
#    {'@DTS:Name': 'CreatorComputerName', '#text': 'AGDGDAP01'},
#    {'@DTS:Name': 'CreationDate',
#     '@DTS:DataType': '7',
#     '#text': '3/30/2011 6:50:48 PM'},
#    {'@DTS:Name': 'PackageType', '#text': '5'},
#    {'@DTS:Name': 'ProtectionLevel', '#text': '0'},
#    {'@DTS:Name': 'MaxConcurrentExecutables', '#text': '-1'},
#    {'@DTS:Name': 'PackagePriorityClass', '#text': '0'},
#    {'@DTS:Name': 'VersionMajor', '#text': '1'},
#    {'@DTS:Name': 'VersionMinor', '#text': '0'},
#    {'@DTS:Name': 'VersionBuild', '#text': '61'},
#    {'@DTS:Name': 'VersionGUID',
#     '#text': '{9B26556B-3267-4495-B4A3-114F329E620B}'},
#    {'@DTS:Name': 'EnableConfig', '#text': '-1'},
# ...
