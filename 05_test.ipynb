# %%
import xml2py

# %%
x = xml2py.dict_load('data/01_basico.dtsx')

# %%
x['Executable']['_ExecutableType']
# Out:
# 'SSIS.Package.2'

# %%
x['Executable'].keys()
# Out:
# dict_keys(['_ExecutableType', 'Property', 'ConnectionManager', 'LoggingOptions', 'Executable', 'PackageVariable'])

# %%
x['Executable']['ConnectionManager'][1]
# Out:
# {'Property': [{'_Name': 'DelayValidation', '_text_': '0'},
#   {'_Name': 'ObjectName', '_text_': 'agdgdbd02.Staging'},
#   {'_Name': 'DTSID', '_text_': '{9EC07AFB-F117-4C7C-9708-D200560034E7}'},
#   {'_Name': 'Description'},
#   {'_Name': 'CreationName', '_text_': 'OLEDB'}],
#  'ObjectData': {'ConnectionManager': {'Property': [{'_Name': 'Retain',
#      '_text_': '0'},
#     {'_Name': 'ConnectionString',
#      '_text_': 'Data Source=agdgdbd02;Initial Catalog=Staging;Provider=SQLNCLI10.1;Integrated Security=SSPI;Application Name=SSIS-01_basico-{9EC07AFB-F117-4C7C-9708-D200560034E7}agdgdbd02.Staging;Auto Translate=False;'}]}}}

# %%
x['Executable']['Executable'].keys()
# Out:
# dict_keys(['_ExecutableType', 'Property', 'LoggingOptions', 'ObjectData'])

# %%
x['Executable']['Executable']['ObjectData']
# Out:
# {'pipeline': {'_id': '0',
#   '_name': 'pipelineXml',
#   '_description': 'pipelineXml',
#   '_defaultBufferMaxRows': '10000',
#   '_engineThreads': '10',
#   '_defaultBufferSize': '10485760',
#   '_BLOBTempStoragePath': '',
#   '_bufferTempStoragePath': '',
#   '_runInOptimizedMode': 'true',
#   'components': {'component': [{'_id': '16',
#      '_name': 'conexion_oledb_dwcorp_source',
#      '_componentClassID': '{BCEFE59B-6819-47F7-A125-63753B33ABB7}',
#      '_description': 'OLE DB Source',
#      '_localeId': '-1',
#      '_usesDispositions': 'true',
#      '_validateExternalMetadata': 'True',
#      '_version': '7',
#      '_pipelineVersion': '0',
#      '_contactInfo': 'OLE DB Source;Microsoft Corporation; Microsoft SqlServer v10; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;7',
#      'properties': {'property': [{'_id': '17',
#         '_name': 'CommandTimeout',
#         '_dataType': 'System.Int32',
#         '_state': 'default',
# ...
